# %%
#Problem-1:Take an integer input and print it.
A=int(input("give an input"))
print(f"The taken input is {A}")

# %%
#problem-2:Take two integer inputs and print their sum.
A=int(input())
B=int(input())
Sum=A+B
print(f"thew summation is {Sum}")

# %%
#problem-3:Take a string input and print it.
Char=input()
print(f"{Char} is a string")

# %%
#problem-4:Take a float input and print its square.
rational=float(input())
square=rational*rational
print(square)

# %%
#problem-5:Take a name as input and print "Hello, [name]!".
name=input()
print(f"hello, {name}")

# %%
#problem-6:Add two numbers.
num1=int(input())
num2=int(input())
print(num1+num2)

# %%
#problem-7:Substract two numbers.
num1=int(input())
num2=int(input())
print(num1-num2)

# %%
#problem-8:Multiply two numbers.
num1=int(input())
num2=int(input())
print(num1*num2)

# %%
#problem-9:Divide two numbers.
num1=int(input())
num2=int(input())
div = num1/num2
print(float(div))

# %%
#Find the remainder when dividing two numbers.
num1=int(input())
num2=int(input())
Rem = num1%num2
print(Rem)

# %%
#Check if a number is even or odd.
N=int(input())
if N%2==0:
    print("Even")
else:
    print("Odd")

# %%
#Check if a number is positive, negative, or zero.
N=int(input())
if N>0:
    print("Positive")
elif N<0:
    print("Negative")
else:
    print("Zero")

# %%
#Find the maximum of two numbers.
A=int(input())
B=int(input())
if A>B:
    print(f"{A} is grater than {B}")
elif B>A:
    print(f"{B} is grater than {A}")
else:
    print("both are equal")

# %%
#Find the minimum of three numbers.
A=int(input())
B=int(input())
C=int(input())
if A>B>C:
    print(f"{A} is grater than {B} and {C}")
elif B>A>C:
    print(f"{B} is grater than {A} and {C}")
elif C>B>A:
    print(f"{C} is grater than {A} and {B}")

# %%
#Check if a number is a multiple of 5.
N=int(input())
if N%5==0:
    print(f"{N} is multiple of 5")

# %%
#Print numbers from 1 to 10 using a for loop.
for i in range(1,11):
    print(i)

# %%
#Print odd numbers from 1 to 20.
for i in range(1,21,2):
    print(i)

# %%
#Print even numbers from 1 to 20.
for i in range(1,21):
    if i%2==0:
        print(i)

# %%
#Print numbers from 10 to 1 in reverse.
for i in range(10,0,-1):
    print(i)

# %%
#Print the multiplication table of a given number.
N=int(input())
for i in range(1,11):
    print(f"{N} * {i} = {N*i}")

# %%
#Create a list with 5 elements and print it.
list = ["mango","banana","kamranga","guava","apple"]
print(list)

# %%
num1 = [10, 20, 30, 40, 50]
print(sum(num1))

# %%
num = [10, 25, 32, 45, 8]
print("largest:", max(num))

# %%
num = [10, 25, 32, 45, 8]
print("smallest:", min(num))

# %%
num = [1, 2, 3, 4, 5]
print("reversed list:", num[::-1])

# %%
text = input("Enter a string: ")
print("length:", len(text))

# %%
text = input("Enter a string: ")
print("uppercase:", text.upper())

# %%
text = input("Enter a string: ")
print("lowercase:", text.lower())

# %%
text = input("Enter a string:")
char = input("Enter a character:")
print(f"occurrences of '{char}':", text.count(char))

# %%
text = input("enter a string: ")
reversed_text = "".join(reversed(text))
print("reversed string:", reversed_text)

# %%
def add(a, b):
    return a + b

print(add(5, 3))

# %%
def square(n):
    return n ** 2

print(square(4))

# %%
def square(n):
    return n ** 2

print(square(4))

# %%
def is_even(n):
    return n % 2 == 0

print(is_even(8))

# %%
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

print(factorial(5))

# %%
def largest(a, b, c):
    return max(a, b, c)

print(largest(10, 25, 7))

# %%
tuple = (1, 2, 3, 4, 5)
print(tuple)

# %%
t = (1, 2, 3, 4)
lst = list(t)
print(lst)

# %%
t = (10, 20, 30, 40, 50)
print("First:", t[0], "Last:", t[-1])

# %%
t = (10, 20, 30, 40, 50)
print("First:", t[0], "Last:", t[-1])

# %%
t = (10, 20, 30, 40)
print("Length:", len(t))

# %%
t = (10, 20, 30, 40)
print("Length:", len(t))

# %%
t = (1, 2, 3, 4, 5)
num = int(input("Enter a number: "))
print("Exists" if num in t else "Does not exist")

# %%
student = {"name": "fahim", "age": 22, "grade": "D"}
print(student)

# %%
print(student["name"])

# %%
student["city"] = "narayanganj"
print(student)

# %%
del student["age"]
print(student)

# %%
for key, value in student.items():
    print(key, ":", value)

# %%
s = {1, 2, 3, 4, 5}
print(s)

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print("Union:", s1 | s2)

# %%
print("Intersection:", s1 & s2)

# %%
print("Difference:", s1 - s2)

# %%
print(2 in s1)
